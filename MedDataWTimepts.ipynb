# %% [markdown]
# <a href="https://colab.research.google.com/github/shelbwearsprada24/my-portfolio/blob/main/MedDataWTimepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
import pandas as pd

drive.mount('/content/drive')
folder_path = '/content/drive/My Drive/ITAN_477'
os.chdir(folder_path)
# !ls

file_name = 'medical_data_with_timepoints.xlsx'
file_path = os.path.join(folder_path, file_name)
df_wide = pd.read_excel(file_path, sheet_name = 'Wide Format')

print(df_wide)

df_long = df_wide.melt(id_vars=['Patient ID', 'Treatment Group', 'Treatment Method'],
                       value_vars=['Pre-Treatment Blood Pressure', '1-Month Post-Treatment Blood Pressure', '3-Month Post-Treatment Blood Pressure'],
                       var_name= 'Time Point', value_name= 'Blood Pressure')
print(df_long)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# medical_data_with_timepoints.xlsx
#     Patient ID Treatment Group Treatment Method  Pre-Treatment Blood Pressure  \
# 0            1         Group A     Medication A                           126
# 1            2         Group B     Medication B                           139
# 2            3         Group B     Medication C                           148
# 3            4         Group A     Medication A                           134
# 4            5         Group A     Medication B                           130
# 5            6         Group A     Medication C                           127
# 6            7         Group C     Medication A                           148
# 7            8         Group C     Medication B                           140
# 8            9         Group C     Medication C                           126
# ...
